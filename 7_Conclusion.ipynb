# %% [markdown]
# NOUS AVONS TESTER NOS ALGORITHMES SUR NOS DIFFERENTS FICHIERS D'ENTRAINEMENT ET DE TEST ET AVONS OBTENU DIFFERENTS **ROOT MEAN SQUARE ERROR** (**RMSE**)POUR CHAQUE MODELE. LES FICHIERS D'ENTRAINEMENT ET DE TESTE ONT ÉTÉ SELECTIONNÉS ALEATOIREMENT PARMI LE DATASET USER.DATA. IL EST DONC NÉCÉSSAIRE POUR OBTENIR L'ERREUR QUADRATIQUE MOYENNE FINALE DE FAIRE LA MOYENNE DES DIFFERENTES RMSE POUR CHAQUE MODELE.

# %% [markdown]
# **MODELE 1**

# %%
rmse_1_1 = 1.3309681924999999
rmse_1_2 = 1.2784006726562502
rmse_1_3 = 1.2356151664062502
rmse_1_4 = 1.2394228276562498
rmse_1_5 = 1.2514344276562501

# %%
rmse_final_1 = (rmse_1_1 + rmse_1_2 + rmse_1_3 + rmse_1_4 + rmse_1_5)/ 5
rmse_final_1
# Out:
# 1.267168257375

# %% [markdown]
# **MODELE 2**

# %%
rmse_2_1 = 1.0679390625704295
rmse_2_2 = 1.0618979279927259
rmse_2_3 = 1.0397125919944021
rmse_2_4 = 1.0340436137860343
rmse_2_5 = 1.0451691045851006

# %%
rmse_final_2 = (rmse_2_1 + rmse_2_2 + rmse_2_3 + rmse_2_4 + rmse_2_5)/ 5
rmse_final_2
# Out:
# 1.0497524601857386

# %% [markdown]
# **MODELE 3**

# %%
rmse_3_1 = 0.9413617020803795
rmse_3_2 = 0.9413752270593589
rmse_3_3 = 0.9430971366624057
rmse_3_4 = 0.9369344757509367
rmse_3_5 = 0.9372725238924561

# %%
rmse_final_3 = (rmse_3_1 + rmse_3_2 + rmse_3_3 + rmse_3_4 + rmse_3_5)/ 5
rmse_final_3
# Out:
# 0.9400082130891073

# %% [markdown]
# **MODELE 4**

# %%
rmse_4_1 = 0.9372809497892511
rmse_4_2 = 0.936592342349124
rmse_4_3 = 0.9352112010961049
rmse_4_4 = 0.93112940677155
rmse_4_5 = 0.931812102436826

# %%
rmse_final_4 = (rmse_4_1 + rmse_4_2 + rmse_4_3 + rmse_4_4 + rmse_4_5)/ 5
rmse_final_4
# Out:
# 0.9344052004885712
